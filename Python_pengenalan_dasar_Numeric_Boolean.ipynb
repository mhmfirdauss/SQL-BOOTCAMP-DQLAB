# %% [markdown]
# # Numeric: Integer & Float
# Pengenalan tipe data numerik

# %%
x = 25

# %%
print(x)
# Out:
# 25

# %%
print(x + 5)
# Out:
# 30

# %%
type(x)
# Out:
# int

# %%
a = 3.5

# %%
print(a)
# Out:
# 3.5

# %%
type(a)
# Out:
# float

# %%
# Penjumlahan
# 25  3.5
print(x + a)
# Out:
# 28.5

# %%
# pengurangan
print(x - a)
# Out:
# 21.5

# %%
# perkalian
print( x * a)
# Out:
# 87.5

# %%
#pembagian
print(x / a)
# Out:
# 7.142857142857143

# %%
# pembagian (pembulatan)
print(x // a)
# Out:
# 7.0

# %%
# Pangkat
# 25 ^ 3.5
print(x ** a)
# Out:
# 78125.0

# %%
# Pangkat2
print(x ** 2)
# Out:
# 625

# %%
# Akar pangkat2
print(x ** (1/2))

print(x ** 0.5)
# Out:
# 5.0
# 5.0

# %%
# pembulatan atas
import math
math.ceil(7/4)
# Out:
# 2

# %%
# pembulatan bawah
import math
math.floor(7/4)
# Out:
# 1

# %%
round(7/4)
# Out:
# 2

# %%
# Modulu/ modulkus / sisa pembagian
print(25 % 2)
# Out:
# 1

# %% [markdown]
# # BOOLEAN
#
# kalau true mau di anggap boolean maka harus pakai T besar (True)

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False
